# %% [markdown]
# # ⚠️ FIRST TIME SETUP ONLY
# ### Run this notebook ONCE. Never again after that.
# ---

# %% [markdown]
# ## Step 1 — Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Step 2 — Download Model to Google Drive
# This downloads Qwen2.5-3B-Instruct (~6GB) directly into your Drive.
# Takes ~15-20 minutes. Only ever run this once.

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="Qwen/Qwen2.5-3B-Instruct",
    local_dir="/content/drive/MyDrive/Qwen2.5-3B-Instruct",
    ignore_patterns=["*.pt", "*.bin"]  # skips redundant files, downloads safetensors only
)

print("✅ Model downloaded to Google Drive!")
# Out:
# ...
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]
# ✅ Model downloaded to Google Drive!

# %% [markdown]
# ## Step 3 — Verify the Download

# %%
import os

model_path = "/content/drive/MyDrive/Qwen2.5-3B-Instruct"
files = os.listdir(model_path)

print("Files in model folder:")
for f in files:
    print(f" - {f}")

# Check key files exist
required = ["config.json", "tokenizer.json", "tokenizer_config.json"]
for r in required:
    status = "✅" if r in files else "❌ MISSING"
    print(f"{status} {r}")
# Out:
# Files in model folder:
#  - .cache
#  - LICENSE
#  - generation_config.json
#  - model-00001-of-00002.safetensors
#  - model-00002-of-00002.safetensors
#  - config.json
#  - README.md
#  - merges.txt
#  - .gitattributes
#  - model.safetensors.index.json
#  - tokenizer.json
#  - tokenizer_config.json
#  - vocab.json
# ✅ config.json
# ✅ tokenizer.json
# ✅ tokenizer_config.json

# %% [markdown]
# ## Step 4 — Install Required Packages
# These get wiped each session, but you can confirm they work here first.

# %%
# !pip install -q transformers peft bitsandbytes trl accelerate huggingface_hub
print("✅ All packages installed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 697.4/697.4 kB 9.7 MB/s eta 0:00:00ta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 13.0 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 11.1 MB/s eta 0:00:0000:0100:01
# ✅ All packages installed

# %% [markdown]
# ---
# ## ✅ Done!
# You never need to run this notebook again.
#
# **From now on, use `every_session.ipynb` at the start of each Colab session.**
